# %% [markdown]
# ### Code for loading and converting the Uchoa benchmark data

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from lib.problems.generator import Generator

sns.set()

# %%
PART = 3
ROOT_DIR = f"./data/VRP/uchoa/"
fstr = f"raw/n{PART}"
DATA_DIR = os.path.join(ROOT_DIR, fstr)
DATA_DIR
# Out:
# './data/VRP/uchoa/raw/n3'

# %%
files = os.listdir(DATA_DIR)
files.sort()
files
# Out:
# ['X-n1001-k43.vrp',
#  'X-n502-k39.vrp',
#  'X-n513-k21.vrp',
#  'X-n524-k153.vrp',
#  'X-n536-k96.vrp',
#  'X-n548-k50.vrp',
#  'X-n561-k42.vrp',
#  'X-n573-k30.vrp',
#  'X-n586-k159.vrp',
#  'X-n599-k92.vrp',
#  'X-n613-k62.vrp',
#  'X-n627-k43.vrp',
#  'X-n641-k35.vrp',
#  'X-n655-k131.vrp',
#  'X-n670-k130.vrp',
#  'X-n685-k75.vrp',
#  'X-n701-k44.vrp',
#  'X-n716-k35.vrp',
#  'X-n733-k159.vrp',
#  'X-n749-k98.vrp',
#  'X-n766-k71.vrp',
#  'X-n783-k48.vrp',
#  'X-n801-k40.vrp',
#  'X-n819-k171.vrp',
#  'X-n837-k142.vrp',
#  'X-n856-k95.vrp',
#  'X-n876-k59.vrp',
#  'X-n895-k37.vrp',
#  'X-n916-k207.vrp',
#  'X-n936-k151.vrp',
#  'X-n957-k87.vrp',
#  'X-n979-k58.vrp']

# %%
instances = []
for f in files:
    load_pth = os.path.join(DATA_DIR, f)
    inst = Generator.load_dataset(load_pth)
    print(load_pth)
    print(inst)
    instances.append(inst[0])
# Out:
# ./data/VRP/uchoa/raw/n3/X-n1001-k43.vrp
# [CCPInstance( coords=ndarray_[1001, 2],  demands=ndarray_[1001],  graph_size=1001,  constraint_value=1.0,  labels=None,  num_components=43)]
# ./data/VRP/uchoa/raw/n3/X-n502-k39.vrp
# [CCPInstance( coords=ndarray_[502, 2],  demands=ndarray_[502],  graph_size=502,  constraint_value=1.0,  labels=None,  num_components=39)]
# ./data/VRP/uchoa/raw/n3/X-n513-k21.vrp
# [CCPInstance( coords=ndarray_[513, 2],  demands=ndarray_[513],  graph_size=513,  constraint_value=1.0,  labels=None,  num_components=21)]
# ./data/VRP/uchoa/raw/n3/X-n524-k153.vrp
# [CCPInstance( coords=ndarray_[524, 2],  demands=ndarray_[524],  graph_size=524,  constraint_value=1.0,  labels=None,  num_components=153)]
# ./data/VRP/uchoa/raw/n3/X-n536-k96.vrp
# [CCPInstance( coords=ndarray_[536, 2],  demands=ndarray_[536],  graph_size=536,  constraint_value=1.0,  labels=None,  num_components=96)]
# ./data/VRP/uchoa/raw/n3/X-n548-k50.vrp
# [CCPInstance( coords=ndarray_[548, 2],  demands=ndarray_[548],  graph_size=548,  constraint_value=1.0,  labels=None,  num_components=50)]
# ./data/VRP/uchoa/raw/n3/X-n561-k42.vrp
# [CCPInstance( coords=ndarray_[561, 2],  demands=ndarray_[561],  graph_size=561,  constraint_value=1.0,  labels=None,  num_components=42)]
# ./data/VRP/uchoa/raw/n3/X-n573-k30.vrp
# [CCPInstance( coords=ndarray_[573, 2],  demands=ndarray_[573],  graph_size=573,  constraint_value=1.0,  labels=None,  num_components=30)]
# ./data/VRP/uchoa/raw/n3/X-n586-k159.vrp
# [CCPInstance( coords=ndarray_[586, 2],  demands=ndarray_[586],  graph_size=586,  constraint_value=1.0,  labels=None,  num_components=159)]
# ./data/VRP/uchoa/raw/n3/X-n599-k92.vrp
# [CCPInstance( coords=ndarray_[599, 2],  demands=ndarray_[599],  graph_size=599,  constraint_value=1.0,  labels=None,  num_components=92)]
# ./data/VRP/uchoa/raw/n3/X-n613-k62.vrp
# [CCPInstance( coords=ndarray_[613, 2],  demands=ndarray_[613],  graph_size=613,  constraint_value=1.0,  labels=None,  num_components=62)]
# ./data/VRP/uchoa/raw/n3/X-n627-k43.vrp
# [CCPInstance( coords=ndarray_[627, 2],  demands=ndarray_[627],  graph_size=627,  constraint_value=1.0,  labels=None,  num_components=43)]
# ./data/VRP/uchoa/raw/n3/X-n641-k35.vrp
# [CCPInstance( coords=ndarray_[641, 2],  demands=ndarray_[641],  graph_size=641,  constraint_value=1.0,  labels=None,  num_components=35)]
# ./data/VRP/uchoa/raw/n3/X-n655-k131.vrp
# [CCPInstance( coords=ndarray_[655, 2],  demands=ndarray_[655],  graph_size=655,  constraint_value=1.0,  labels=None,  num_components=131)]
# ./data/VRP/uchoa/raw/n3/X-n670-k130.vrp
# [CCPInstance( coords=ndarray_[670, 2],  demands=ndarray_[670],  graph_size=670,  constraint_value=1.0,  labels=None,  num_components=130)]
# ./data/VRP/uchoa/raw/n3/X-n685-k75.vrp
# [CCPInstance( coords=ndarray_[685, 2],  demands=ndarray_[685],  graph_size=685,  constraint_value=1.0,  labels=None,  num_components=75)]
# ./data/VRP/uchoa/raw/n3/X-n701-k44.vrp
# [CCPInstance( coords=ndarray_[701, 2],  demands=ndarray_[701],  graph_size=701,  constraint_value=1.0,  labels=None,  num_components=44)]
# ./data/VRP/uchoa/raw/n3/X-n716-k35.vrp
# [CCPInstance( coords=ndarray_[716, 2],  demands=ndarray_[716],  graph_size=716,  constraint_value=1.0,  labels=None,  num_components=35)]
# ./data/VRP/uchoa/raw/n3/X-n733-k159.vrp
# [CCPInstance( coords=ndarray_[733, 2],  demands=ndarray_[733],  graph_size=733,  constraint_value=1.0,  labels=None,  num_components=159)]
# ./data/VRP/uchoa/raw/n3/X-n749-k98.vrp
# [CCPInstance( coords=ndarray_[749, 2],  demands=ndarray_[749],  graph_size=749,  constraint_value=1.0,  labels=None,  num_components=98)]
# ./data/VRP/uchoa/raw/n3/X-n766-k71.vrp
# [CCPInstance( coords=ndarray_[766, 2],  demands=ndarray_[766],  graph_size=766,  constraint_value=1.0,  labels=None,  num_components=71)]
# ./data/VRP/uchoa/raw/n3/X-n783-k48.vrp
# [CCPInstance( coords=ndarray_[783, 2],  demands=ndarray_[783],  graph_size=783,  constraint_value=1.0,  labels=None,  num_components=48)]
# ./data/VRP/uchoa/raw/n3/X-n801-k40.vrp
# [CCPInstance( coords=ndarray_[801, 2],  demands=ndarray_[801],  graph_size=801,  constraint_value=1.0,  labels=None,  num_components=40)]
# ./data/VRP/uchoa/raw/n3/X-n819-k171.vrp
# [CCPInstance( coords=ndarray_[819, 2],  demands=ndarray_[819],  graph_size=819,  constraint_value=1.0,  labels=None,  num_components=171)]
# ./data/VRP/uchoa/raw/n3/X-n837-k142.vrp
# [CCPInstance( coords=ndarray_[837, 2],  demands=ndarray_[837],  graph_size=837,  constraint_value=1.0,  labels=None,  num_components=142)]
# ./data/VRP/uchoa/raw/n3/X-n856-k95.vrp
# [CCPInstance( coords=ndarray_[856, 2],  demands=ndarray_[856],  graph_size=856,  constraint_value=1.0,  labels=None,  num_components=95)]
# ./data/VRP/uchoa/raw/n3/X-n876-k59.vrp
# [CCPInstance( coords=ndarray_[876, 2],  demands=ndarray_[876],  graph_size=876,  constraint_value=1.0,  labels=None,  num_components=59)]
# ./data/VRP/uchoa/raw/n3/X-n895-k37.vrp
# [CCPInstance( coords=ndarray_[895, 2],  demands=ndarray_[895],  graph_size=895,  constraint_value=1.0,  labels=None,  num_components=37)]
# ./data/VRP/uchoa/raw/n3/X-n916-k207.vrp
# [CCPInstance( coords=ndarray_[916, 2],  demands=ndarray_[916],  graph_size=916,  constraint_value=1.0,  labels=None,  num_components=207)]
# ./data/VRP/uchoa/raw/n3/X-n936-k151.vrp
# [CCPInstance( coords=ndarray_[936, 2],  demands=ndarray_[936],  graph_size=936,  constraint_value=1.0,  labels=None,  num_components=151)]
# ./data/VRP/uchoa/raw/n3/X-n957-k87.vrp
# [CCPInstance( coords=ndarray_[957, 2],  demands=ndarray_[957],  graph_size=957,  constraint_value=1.0,  labels=None,  num_components=87)]
# ./data/VRP/uchoa/raw/n3/X-n979-k58.vrp
# [CCPInstance( coords=ndarray_[979, 2],  demands=ndarray_[979],  graph_size=979,  constraint_value=1.0,  labels=None,  num_components=58)]

# %%
instances
# Out:
# [CCPInstance( coords=ndarray_[1001, 2],  demands=ndarray_[1001],  graph_size=1001,  constraint_value=1.0,  labels=None,  num_components=43),
#  CCPInstance( coords=ndarray_[502, 2],  demands=ndarray_[502],  graph_size=502,  constraint_value=1.0,  labels=None,  num_components=39),
#  CCPInstance( coords=ndarray_[513, 2],  demands=ndarray_[513],  graph_size=513,  constraint_value=1.0,  labels=None,  num_components=21),
#  CCPInstance( coords=ndarray_[524, 2],  demands=ndarray_[524],  graph_size=524,  constraint_value=1.0,  labels=None,  num_components=153),
#  CCPInstance( coords=ndarray_[536, 2],  demands=ndarray_[536],  graph_size=536,  constraint_value=1.0,  labels=None,  num_components=96),
#  CCPInstance( coords=ndarray_[548, 2],  demands=ndarray_[548],  graph_size=548,  constraint_value=1.0,  labels=None,  num_components=50),
#  CCPInstance( coords=ndarray_[561, 2],  demands=ndarray_[561],  graph_size=561,  constraint_value=1.0,  labels=None,  num_components=42),
#  CCPInstance( coords=ndarray_[573, 2],  demands=ndarray_[573],  graph_size=573,  constraint_value=1.0,  labels=None,  num_components=30),
#  CCPInstance( coords=ndarray_[586, 2],  demands=ndarray_[586],  graph_size=586,  constraint_value=1.0,  labels=None,  num_components=159),
#  CCPInstance( coords=ndarray_[599, 2],  demands=ndarray_[599],  graph_size=599,  constraint_value=1.0,  labels=None,  num_components=92),
#  CCPInstance( coords=ndarray_[613, 2],  demands=ndarray_[613],  graph_size=613,  constraint_value=1.0,  labels=None,  num_components=62),
#  CCPInstance( coords=ndarray_[627, 2],  demands=ndarray_[627],  graph_size=627,  constraint_value=1.0,  labels=None,  num_components=43),
#  CCPInstance( coords=ndarray_[641, 2],  demands=ndarray_[641],  graph_size=641,  constraint_value=1.0,  labels=None,  num_components=35),
#  CCPInstance( coords=ndarray_[655, 2],  demands=ndarray_[655],  graph_size=655,  constraint_value=1.0,  labels=None,  num_components=131),
#  CCPInstance( coords=ndarray_[670, 2],  demands=ndarray_[670],  graph_size=670,  constraint_value=1.0,  labels=None,  num_components=130),
#  CCPInstance( coords=ndarray_[685, 2],  demands=ndarray_[685],  graph_size=685,  constraint_value=1.0,  labels=None,  num_components=75),
#  CCPInstance( coords=ndarray_[701, 2],  demands=ndarray_[701],  graph_size=701,  constraint_value=1.0,  labels=None,  num_components=44),
#  CCPInstance( coords=ndarray_[716, 2],  demands=ndarray_[716],  graph_size=716,  constraint_value=1.0,  labels=None,  num_components=35),
#  CCPInstance( coords=ndarray_[733, 2],  demands=ndarray_[733],  graph_size=733,  constraint_value=1.0,  labels=None,  num_components=159),
#  CCPInstance( coords=ndarray_[749, 2],  demands=ndarray_[749],  graph_size=749,  constraint_value=1.0,  labels=None,  num_components=98),
#  CCPInstance( coords=ndarray_[766, 2],  demands=ndarray_[766],  graph_size=766,  constraint_value=1.0,  labels=None,  num_components=71),
#  CCPInstance( coords=ndarray_[783, 2],  demands=ndarray_[783],  graph_size=783,  constraint_value=1.0,  labels=None,  num_components=48),
#  CCPInstance( coords=ndarray_[801, 2],  demands=ndarray_[801],  graph_size=801,  constraint_value=1.0,  labels=None,  num_components=40),
#  CCPInstance( coords=ndarray_[819, 2],  demands=ndarray_[819],  graph_size=819,  constraint_value=1.0,  labels=None,  num_components=171),
#  CCPInstance( coords=ndarray_[837, 2],  demands=ndarray_[837],  graph_size=837,  constraint_value=1.0,  labels=None,  num_components=142),
#  CCPInstance( coords=ndarray_[856, 2],  demands=ndarray_[856],  graph_size=856,  constraint_value=1.0,  labels=None,  num_components=95),
#  CCPInstance( coords=ndarray_[876, 2],  demands=ndarray_[876],  graph_size=876,  constraint_value=1.0,  labels=None,  num_components=59),
#  CCPInstance( coords=ndarray_[895, 2],  demands=ndarray_[895],  graph_size=895,  constraint_value=1.0,  labels=None,  num_components=37),
#  CCPInstance( coords=ndarray_[916, 2],  demands=ndarray_[916],  graph_size=916,  constraint_value=1.0,  labels=None,  num_components=207),
#  CCPInstance( coords=ndarray_[936, 2],  demands=ndarray_[936],  graph_size=936,  constraint_value=1.0,  labels=None,  num_components=151),
#  CCPInstance( coords=ndarray_[957, 2],  demands=ndarray_[957],  graph_size=957,  constraint_value=1.0,  labels=None,  num_components=87),
#  CCPInstance( coords=ndarray_[979, 2],  demands=ndarray_[979],  graph_size=979,  constraint_value=1.0,  labels=None,  num_components=58)]

# %%
save_pth = os.path.join(ROOT_DIR, f"n{PART}.npz")
Generator.save_dataset(instances, filepath=save_pth, problem="vrp")
# Out:
# Dataset file with same name exists already. Overwrite file? (y/n)
# /mnt/_data/PycharmProjects/cluster2route/lib/problems/generator.py:111: UserWarning: array shapes do not match. Saving as pickled object array.
#   warn(f"array shapes do not match. Saving as pickled object array.")
# 'data/VRP/uchoa/n3.npz'

# %%
spth = os.path.join(ROOT_DIR, f"n{PART}.npz")
instances = Generator.load_dataset(spth, allow_pickle=True)
instances
# Out:
# [CCPInstance( coords=ndarray_[1001, 2],  demands=ndarray_[1001],  graph_size=1001,  constraint_value=1.0,  labels=None,  num_components=43),
#  CCPInstance( coords=ndarray_[502, 2],  demands=ndarray_[502],  graph_size=502,  constraint_value=1.0,  labels=None,  num_components=39),
#  CCPInstance( coords=ndarray_[513, 2],  demands=ndarray_[513],  graph_size=513,  constraint_value=1.0,  labels=None,  num_components=21),
#  CCPInstance( coords=ndarray_[524, 2],  demands=ndarray_[524],  graph_size=524,  constraint_value=1.0,  labels=None,  num_components=153),
#  CCPInstance( coords=ndarray_[536, 2],  demands=ndarray_[536],  graph_size=536,  constraint_value=1.0,  labels=None,  num_components=96),
#  CCPInstance( coords=ndarray_[548, 2],  demands=ndarray_[548],  graph_size=548,  constraint_value=1.0,  labels=None,  num_components=50),
#  CCPInstance( coords=ndarray_[561, 2],  demands=ndarray_[561],  graph_size=561,  constraint_value=1.0,  labels=None,  num_components=42),
#  CCPInstance( coords=ndarray_[573, 2],  demands=ndarray_[573],  graph_size=573,  constraint_value=1.0,  labels=None,  num_components=30),
#  CCPInstance( coords=ndarray_[586, 2],  demands=ndarray_[586],  graph_size=586,  constraint_value=1.0,  labels=None,  num_components=159),
#  CCPInstance( coords=ndarray_[599, 2],  demands=ndarray_[599],  graph_size=599,  constraint_value=1.0,  labels=None,  num_components=92),
#  CCPInstance( coords=ndarray_[613, 2],  demands=ndarray_[613],  graph_size=613,  constraint_value=1.0,  labels=None,  num_components=62),
#  CCPInstance( coords=ndarray_[627, 2],  demands=ndarray_[627],  graph_size=627,  constraint_value=1.0,  labels=None,  num_components=43),
#  CCPInstance( coords=ndarray_[641, 2],  demands=ndarray_[641],  graph_size=641,  constraint_value=1.0,  labels=None,  num_components=35),
#  CCPInstance( coords=ndarray_[655, 2],  demands=ndarray_[655],  graph_size=655,  constraint_value=1.0,  labels=None,  num_components=131),
#  CCPInstance( coords=ndarray_[670, 2],  demands=ndarray_[670],  graph_size=670,  constraint_value=1.0,  labels=None,  num_components=130),
#  CCPInstance( coords=ndarray_[685, 2],  demands=ndarray_[685],  graph_size=685,  constraint_value=1.0,  labels=None,  num_components=75),
#  CCPInstance( coords=ndarray_[701, 2],  demands=ndarray_[701],  graph_size=701,  constraint_value=1.0,  labels=None,  num_components=44),
#  CCPInstance( coords=ndarray_[716, 2],  demands=ndarray_[716],  graph_size=716,  constraint_value=1.0,  labels=None,  num_components=35),
#  CCPInstance( coords=ndarray_[733, 2],  demands=ndarray_[733],  graph_size=733,  constraint_value=1.0,  labels=None,  num_components=159),
#  CCPInstance( coords=ndarray_[749, 2],  demands=ndarray_[749],  graph_size=749,  constraint_value=1.0,  labels=None,  num_components=98),
#  CCPInstance( coords=ndarray_[766, 2],  demands=ndarray_[766],  graph_size=766,  constraint_value=1.0,  labels=None,  num_components=71),
#  CCPInstance( coords=ndarray_[783, 2],  demands=ndarray_[783],  graph_size=783,  constraint_value=1.0,  labels=None,  num_components=48),
#  CCPInstance( coords=ndarray_[801, 2],  demands=ndarray_[801],  graph_size=801,  constraint_value=1.0,  labels=None,  num_components=40),
#  CCPInstance( coords=ndarray_[819, 2],  demands=ndarray_[819],  graph_size=819,  constraint_value=1.0,  labels=None,  num_components=171),
#  CCPInstance( coords=ndarray_[837, 2],  demands=ndarray_[837],  graph_size=837,  constraint_value=1.0,  labels=None,  num_components=142),
#  CCPInstance( coords=ndarray_[856, 2],  demands=ndarray_[856],  graph_size=856,  constraint_value=1.0,  labels=None,  num_components=95),
#  CCPInstance( coords=ndarray_[876, 2],  demands=ndarray_[876],  graph_size=876,  constraint_value=1.0,  labels=None,  num_components=59),
#  CCPInstance( coords=ndarray_[895, 2],  demands=ndarray_[895],  graph_size=895,  constraint_value=1.0,  labels=None,  num_components=37),
#  CCPInstance( coords=ndarray_[916, 2],  demands=ndarray_[916],  graph_size=916,  constraint_value=1.0,  labels=None,  num_components=207),
#  CCPInstance( coords=ndarray_[936, 2],  demands=ndarray_[936],  graph_size=936,  constraint_value=1.0,  labels=None,  num_components=151),
#  CCPInstance( coords=ndarray_[957, 2],  demands=ndarray_[957],  graph_size=957,  constraint_value=1.0,  labels=None,  num_components=87),
#  CCPInstance( coords=ndarray_[979, 2],  demands=ndarray_[979],  graph_size=979,  constraint_value=1.0,  labels=None,  num_components=58)]

# %%
COLS = ["x_coord", "y_coord", "demand"]
i = 0
for inst in instances:
    df_ = pd.DataFrame(
        data=np.concatenate((inst.coords, inst.demands[:, None]), axis=-1),
        columns=COLS
    )
    sns.relplot(x="x_coord", y="y_coord", size="demand",
                sizes=(10, 100), alpha=.5, palette="muted",
                height=6, data=df_)
    plt.scatter(inst.coords[0, 0], inst.coords[0, 1], c="red", marker="*", s=100)
    i += 1
    if i > 10:
        break
